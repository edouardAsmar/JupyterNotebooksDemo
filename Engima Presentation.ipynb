# %% [markdown]
# # Jupyter Notebook Demo
# ## Analyzing a new website's data

# %% [markdown]
# ## Required imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# ## Importing data into the notebook from a csv file

# %%
rawdata = []
with open ("/Users/edouardasmar/serviceboxanalytics.csv", "rb") as csvfile:
    reader = csv.DictReader(csvfile, dialect="excel")
    for row in reader:
        rawdata.append(row)

# %% [markdown]
# ### Moving the data into a pandas Data Frame
#
# * Data frames are equivalent to tables in languages like SQL

# %%
df = pd.DataFrame(rawdata)

# %% [markdown]
# ### The Data Frame:
#
# * In SQL:
#     ``` use df; select top * from df; ```

# %%
df
# Out:
#            bounces        date daysSinceLastSession entrances  \
# 0        1       3  2016-06-18                    0         3
# 1        2       1  2016-06-18                    0         1
# 2        3       1  2016-06-18                    1         1
# 3        4       0  2016-06-18                    0         1
# 4        5       0  2016-06-18                    0         0
# 5        6       0  2016-06-18                    0         1
# 6        7       0  2016-06-18                    0         0
# 7        8       0  2016-06-18                    0         0
# 8        9       0  2016-06-18                    0         0
# 9       10       0  2016-06-18                    0         0
# 10      11       0  2016-06-18                    0         0
# 11      12       0  2016-06-18                   11         0
# 12      13       0  2016-06-18                   11         1
# 13      14       0  2016-06-18                    0         0
# 14      15       0  2016-06-18                    0         1
# 15      16       0  2016-06-18                    0         0
# 16      17       0  2016-06-18                    0         1
# 17      18       1  2016-06-19                    0         1
# 18      19       1  2016-06-19                    0         1
# 19      20       1  2016-06-19                    0         1
# 20      21       0  2016-06-19                    1         1
# 21      22       0  2016-06-19                    1         0
# 22      23       0  2016-06-19                    0         1
# 23      24       0  2016-06-19                    0         0
# 24      25       0  2016-06-19                    1         1
# 25      26       0  2016-06-19                    1         0
# 26      27       0  2016-06-19                    1         0
# 27      28       2  2016-06-20                    0         2
# 28      29       1  2016-06-20                    0         1
# 29      30       1  2016-06-20                    0         1
# ...    ...     ...         ...                  ...       ...
# 1629  1630       0  2016-07-18                   14         1
# 1630  1631       0  2016-07-18                   14         0
# 1631  1632       0  2016-07-18                   14         0
# 1632  1633       0  2016-07-18                   14         0
# 1633  1634       0  2016-07-18                   14         0
# 1634  1635       0  2016-07-18                   14         0
# 1635  1636       0  2016-07-18                   14         0
# 1636  1637       0  2016-07-18                    0         1
# 1637  1638       0  2016-07-18                    0         0
# 1638  1639       0  2016-07-18                    0         0
# 1639  1640       0  2016-07-18                    0         0
# 1640  1641       0  2016-07-18                    0         0
# 1641  1642       0  2016-07-18                    0         0
# 1642  1643       0  2016-07-18                    0         0
# 1643  1644       0  2016-07-18                    0         0
# 1644  1645       0  2016-07-18                    0         0
# 1645  1646       0  2016-07-18                    0         1
# 1646  1647       0  2016-07-18                    0         0
# 1647  1648       0  2016-07-18                    0         0
# 1648  1649       0  2016-07-18                    0         0
# 1649  1650       0  2016-07-18                    0         0
# 1650  1651       0  2016-07-18                    0         0
# 1651  1652       0  2016-07-18                    0         0
# 1652  1653       0  2016-07-18                    0         1
# 1653  1654       0  2016-07-18                    0         0
# 1654  1655       0  2016-07-18                    0         0
# 1655  1656       0  2016-07-18                    0         0
# 1656  1657       0  2016-07-18                    0         1
# 1657  1658       0  2016-07-18                    0         0
# 1658  1659       0  2016-07-18                    0         0
#
#               exitPagePath newUsers pageLoadTime              pagePath  \
# 0                        /        3            0                     /
# 1     /tourist-attractions        1            0  /tourist-attractions
# 2                        /        0            0                     /
# 3     /standardlesothobank        0            0                     /
# 4     /standardlesothobank        0            0  /standardlesothobank
# 5                   /mpesa        0            0                     /
# 6                   /mpesa        0            0        /accommodation
# 7                   /mpesa        0            0   /contacts/emergency
# 8                   /mpesa        0            0                /mpesa
# 9                   /mpesa        0            0  /standardlesothobank
# 10                  /mpesa        0            0  /tourist-attractions
# 11    /tourist-attractions        0            0        /accommodation
# 12    /tourist-attractions        0            0  /tourist-attractions
# 13          /accommodation        0            0        /accommodation
# 14          /accommodation        1            0  /tourist-attractions
# 15    /standardlesothobank        0            0  /standardlesothobank
# 16    /standardlesothobank        0            0  /tourist-attractions
# 17                       /        1            0                     /
# 18    /tourist-attractions        1            0  /tourist-attractions
# 19                  /mpesa        0            0                /mpesa
# 20                  /mpesa        0            0                     /
# 21                  /mpesa        0            0                /mpesa
# 22                  /mpesa        0            0                     /
# 23                  /mpesa        0            0                /mpesa
# 24                  /mpesa        0            0                     /
# 25                  /mpesa        0            0        /accommodation
# 26                  /mpesa        0            0                /mpesa
# 27                       /        2            0                     /
# 28                  /mpesa        1            0                /mpesa
# 29    /tourist-attractions        0            0  /tourist-attractions
# ...                    ...      ...          ...                   ...
# 1629              /ecocash        0            0                     /
# 1630              /ecocash        0            0              /ecocash
# 1631              /ecocash        0            0                /mpesa
# 1632              /ecocash        0            0               /police
# 1633              /ecocash        0            0  /standardlesothobank
# 1634              /ecocash        0            0      /telephone-taxis
# 1635              /ecocash        0            0  /tourist-attractions
# 1636            /emergency        1            0                     /
# 1637            /emergency        0            0        /accommodation
# 1638            /emergency        0            0              /ecocash
# 1639            /emergency        0            0            /emergency
# 1640            /emergency        0            0                /mpesa
# 1641            /emergency        0            0               /police
# 1642            /emergency        0            0  /standardlesothobank
# 1643            /emergency        0            0      /telephone-taxis
# 1644            /emergency        0            0  /tourist-attractions
# 1645  /tourist-attractions        1            0                     /
# 1646  /tourist-attractions        0            0        /accommodation
# 1647  /tourist-attractions        0            0            /emergency
# 1648  /tourist-attractions        0            0                /mpesa
# 1649  /tourist-attractions        0            0               /police
# 1650  /tourist-attractions        0            0      /telephone-taxis
# 1651  /tourist-attractions        0            0  /tourist-attractions
# 1652        /accommodation        1         8456                     /
# 1653        /accommodation        0        10616        /accommodation
# 1654        /accommodation        0         5477               /police
# 1655        /accommodation        0        30794  /tourist-attractions
# 1656        /accommodation        1            0                     /
# 1657        /accommodation        0            0        /accommodation
# 1658        /accommodation        0            0               /police
#
#      pageviews sessionCount sessionDurationBucket sessions sessionsPerUser  \
# 0            3            1                     0        3               1
# 1            1            1                     0        1               1
# 2            1            4                     0        1               1
# 3            1           60                    11        1               1
# 4            1           60                    11        0               0
# 5            2          140                 11560        1               1
# 6            1          140                 11560        0               0
# 7            1          140                 11560        0               0
# 8           30          140                 11560        0               0
# 9            9          140                 11560        0               0
# 10          18          140                 11560        0               0
# 11           1            4                   207        0               0
# 12           2            4                   207        1               1
# 13           1            1                    86        0               0
# 14           1            1                    86        1               1
# 15           1          141                    87        0               0
# 16           1          141                    87        1               1
# 17           1            1                     0        1               1
# 18           1            1                     0        1               1
# 19           1           62                     0        1               1
# 20           2          143                   515        1               1
# 21           2          143                   515        0               0
# 22           1          144                  5768        1               1
# 23          31          144                  5768        0               0
# 24           2           61                   727        1               1
# 25           4           61                   727        0               0
# 26           3           61                   727        0               0
# 27           2            1                     0        2               1
# 28           1            1                     0        1               1
# 29           1            2                     0        1               1
# ...        ...          ...                   ...      ...             ...
# 1629         2           14                   908        1               1
# 1630         2           14                   908        0               0
# 1631         3           14                   908        0               0
# 1632         1           14                   908        0               0
# 1633         1           14                   908        0               0
# 1634         1           14                   908        0               0
# 1635         1           14                   908        0               0
# 1636         4            1                   909        1               1
# 1637         1            1                   909        0               0
# 1638         1            1                   909        0               0
# 1639         1            1                   909        0               0
# 1640         1            1                   909        0               0
# 1641         2            1                   909        0               0
# 1642         1            1                   909        0               0
# 1643         1            1                   909        0               0
# 1644         2            1                   909        0               0
# 1645         2            1                   944        1               1
# 1646         1            1                   944        0               0
# 1647         1            1                   944        0               0
# 1648         1            1                   944        0               0
# 1649         1            1                   944        0               0
# 1650         1            1                   944        0               0
# 1651         2            1                   944        0               0
# 1652         1            1                   945        1               1
# 1653         2            1                   945        0               0
# 1654         1            1                   945        0               0
# 1655         2            1                   945        0               0
# 1656         1            1                    96        1               1
# 1657         1            1                    96        0               0
# 1658         1            1                    96        0               0
#
#      timeOnPage           userType users
# 0             0        New Visitor     3
# 1             0        New Visitor     1
# 2             0  Returning Visitor     1
# 3            11  Returning Visitor     1
# 4             0  Returning Visitor     1
# 5           382  Returning Visitor     1
# 6            93  Returning Visitor     1
# 7            31  Returning Visitor     1
# 8          7182  Returning Visitor     1
# 9          2201  Returning Visitor     1
# 10         1677  Returning Visitor     1
# 11          134  Returning Visitor     1
# 12           73  Returning Visitor     1
# 13            0        New Visitor     1
# 14           86        New Visitor     1
# 15            0  Returning Visitor     1
# 16           87  Returning Visitor     1
# 17            0        New Visitor     1
# 18            0        New Visitor     1
# 19            0  Returning Visitor     1
# 20          117  Returning Visitor     1
# 21          398  Returning Visitor     1
# 22           16  Returning Visitor     1
# 23         5753  Returning Visitor     1
# 24           22  Returning Visitor     1
# 25          159  Returning Visitor     1
# 26          546  Returning Visitor     1
# 27            0        New Visitor     2
# 28            0        New Visitor     1
# 29            0  Returning Visitor     1
# ...         ...                ...   ...
# 1629        182  Returning Visitor     1
# 1630        251  Returning Visitor     1
# 1631        143  Returning Visitor     1
# 1632        251  Returning Visitor     1
# 1633         10  Returning Visitor     1
# 1634         40  Returning Visitor     1
# 1635         31  Returning Visitor     1
# 1636        144        New Visitor     1
# 1637         49        New Visitor     1
# 1638         87        New Visitor     1
# 1639          0        New Visitor     1
# 1640        189        New Visitor     1
# 1641         81        New Visitor     1
# 1642        226        New Visitor     1
# 1643         67        New Visitor     1
# 1644         64        New Visitor     1
# 1645        152        New Visitor     1
# 1646        192        New Visitor     1
# 1647         51        New Visitor     1
# 1648        255        New Visitor     1
# 1649        126        New Visitor     1
# 1650         25        New Visitor     1
# 1651        143        New Visitor     1
# 1652        240        New Visitor     1
# 1653        138        New Visitor     1
# 1654        477        New Visitor     1
# 1655         90        New Visitor     1
# 1656         25        New Visitor     1
# 1657          0        New Visitor     1
# 1658         71        New Visitor     1
#
# [1659 rows x 17 columns]

# %% [markdown]
# ## dtypes allows you to check the types of each column in the data frame

# %%
df.dtypes
# Out:
#                          object
# bounces                  object
# date                     object
# daysSinceLastSession     object
# entrances                object
# exitPagePath             object
# newUsers                 object
# pageLoadTime             object
# pagePath                 object
# pageviews                object
# sessionCount             object
# sessionDurationBucket    object
# sessions                 object
# sessionsPerUser          object
# timeOnPage               object
# userType                 object
# users                    object
# dtype: object

# %% [markdown]
# ## Use ```head()``` and ```tail()``` to see top 5 and bottom 5 results

# %%
df.head()
# Out:
#      bounces        date daysSinceLastSession entrances          exitPagePath  \
# 0  1       3  2016-06-18                    0         3                     /
# 1  2       1  2016-06-18                    0         1  /tourist-attractions
# 2  3       1  2016-06-18                    1         1                     /
# 3  4       0  2016-06-18                    0         1  /standardlesothobank
# 4  5       0  2016-06-18                    0         0  /standardlesothobank
#
#   newUsers pageLoadTime              pagePath pageviews sessionCount  \
# 0        3            0                     /         3            1
# 1        1            0  /tourist-attractions         1            1
# 2        0            0                     /         1            4
# 3        0            0                     /         1           60
# 4        0            0  /standardlesothobank         1           60
#
#   sessionDurationBucket sessions sessionsPerUser timeOnPage  \
# 0                     0        3               1          0
# 1                     0        1               1          0
# 2                     0        1               1          0
# 3                    11        1               1         11
# 4                    11        0               0          0
#
#             userType users
# 0        New Visitor     3
# 1        New Visitor     1
# 2  Returning Visitor     1
# 3  Returning Visitor     1
# 4  Returning Visitor     1

# %%
df.tail()
# Out:
#            bounces        date daysSinceLastSession entrances    exitPagePath  \
# 1654  1655       0  2016-07-18                    0         0  /accommodation
# 1655  1656       0  2016-07-18                    0         0  /accommodation
# 1656  1657       0  2016-07-18                    0         1  /accommodation
# 1657  1658       0  2016-07-18                    0         0  /accommodation
# 1658  1659       0  2016-07-18                    0         0  /accommodation
#
#      newUsers pageLoadTime              pagePath pageviews sessionCount  \
# 1654        0         5477               /police         1            1
# 1655        0        30794  /tourist-attractions         2            1
# 1656        1            0                     /         1            1
# 1657        0            0        /accommodation         1            1
# 1658        0            0               /police         1            1
#
#      sessionDurationBucket sessions sessionsPerUser timeOnPage     userType  \
# 1654                   945        0               0        477  New Visitor
# 1655                   945        0               0         90  New Visitor
# 1656                    96        1               1         25  New Visitor
# 1657                    96        0               0          0  New Visitor
# 1658                    96        0               0         71  New Visitor
#
#      users
# 1654     1
# 1655     1
# 1656     1
# 1657     1
# 1658     1

# %% [markdown]
# ## Selection, group by and functions
# * Selectng specific columns
# * Group by and max

# %%
df[['newUsers', 'date']].groupby('date').max()
# Out:
#            newUsers
# date
# 2016-06-18        3
# 2016-06-19        1
# 2016-06-20        2
# 2016-06-21        0
# 2016-06-22        1
# 2016-06-23        2
# 2016-06-24        1
# 2016-06-25        1
# 2016-06-26        1
# 2016-06-27        1
# 2016-06-28        1
# 2016-06-29        1
# 2016-06-30        1
# 2016-07-01        8
# 2016-07-02        1
# 2016-07-03        0
# 2016-07-04        3
# 2016-07-05        1
# 2016-07-06        2
# 2016-07-07        2
# 2016-07-08        2
# 2016-07-09        2
# 2016-07-10        2
# 2016-07-11        2
# 2016-07-12        4
# 2016-07-13        1
# 2016-07-14        1
# 2016-07-15        8
# 2016-07-16        8
# 2016-07-17        3
# 2016-07-18       22

# %% [markdown]
# ## Changing types
# * ```astype(type=)```

# %%
df[['entrances','bounces','newUsers','daysSinceLastSession','pageLoadTime', 'pageviews', 'timeOnPage','sessionDurationBucket', 'users', 'sessionCount', 'sessions', 'sessionsPerUser']] = df[['entrances','bounces','newUsers','daysSinceLastSession','pageLoadTime', 'pageviews', 'timeOnPage','sessionDurationBucket', 'users','sessionCount', 'sessions', 'sessionsPerUser']].astype(int)

# %%
df.dtypes
# Out:
#                          object
# bounces                   int64
# date                     object
# daysSinceLastSession      int64
# entrances                 int64
# exitPagePath             object
# newUsers                  int64
# pageLoadTime              int64
# pagePath                 object
# pageviews                 int64
# sessionCount              int64
# sessionDurationBucket     int64
# sessions                  int64
# sessionsPerUser           int64
# timeOnPage                int64
# userType                 object
# users                     int64
# dtype: object

# %%
df[['exitPagePath', 'pagePath', 'userType']] = df[['exitPagePath', 'pagePath', 'userType']].astype(str)

# %%
df.dtypes
# Out:
#                          object
# bounces                   int64
# date                     object
# daysSinceLastSession      int64
# entrances                 int64
# exitPagePath             object
# newUsers                  int64
# pageLoadTime              int64
# pagePath                 object
# pageviews                 int64
# sessionCount              int64
# sessionDurationBucket     int64
# sessions                  int64
# sessionsPerUser           int64
# timeOnPage                int64
# userType                 object
# users                     int64
# dtype: object

# %% [markdown]
# ## Creating sub-tables out of results
# * Simply assign the results to a new variable
# * In SQL:
#     ``` select a.exitPagePath as exit, sum(a.entrances) as entrances from df as a group by exit ```

# %%
entrancesAndExits = df[['exitPagePath', 'entrances']].groupby('exitPagePath').sum()
entrancesAndExits
# Out:
#                                       entrances
# exitPagePath
# /                                           217
# /accommodation                               45
# /contacts/emergency                           3
# /directions?end=-29.315504,27.489813          1
# /directions?end=-29.316257,27.478507          1
# /ecocash                                     18
# /emergency                                   16
# /mpesa                                       27
# /police                                      27
# /slideimages/ads/slide1.jpg                   1
# /standardlesothobank                         55
# /telephone-taxis                             13
# /tourism-attractions                          1
# /tourism/attractions                          1
# /tourist-attractions                        581

# %% [markdown]
# ## Making a visualization
# * Use the plot library by calling ```.plot.[plotType]()```
# * For the visualization to appear inline must call ```%matplotlib inline```
# * Say your boss asks:
#     * What are common entry/exit points for the website?
#     * How many times has each page been viewed?
#     * Can make some sample visualizations to answer these questions

# %%
# %matplotlib inline

# %%
entrancesAndPages = df[['exitPagePath', 'entrances']].groupby('exitPagePath').count()
entrancesAndPages.plot.bar()

# %%
pageViewsAndPages = df[['pagePath', 'pageviews']].groupby('pagePath').sum()
pageViewsAndPages.plot.bar()

# %% [markdown]
# ## Your boss now asks:
# * What regions and cities does traffic come from?
# * How many new users each day?
# * What devices and OSs are accessing the website?
#
# ## Let's walk through how to protype answers to these questions

# %% [markdown]
# ### First load in the relevant data

# %%
rawdata = []
with open ("/Users/edouardasmar/regionanddeviceservicebox.csv", "rb") as csvfile:
    reader = csv.DictReader(csvfile, dialect="excel")
    for row in reader:
        rawdata.append(row)

# %%
df2 = pd.DataFrame(rawdata)

# %%
df2
# Out:
#          bounces          browser            city deviceCategory entrances  \
# 0      1       3  Android Browser          Maseru         mobile         4
# 1      2       2  Android Browser           Berea         mobile         2
# 2      3       0  Android Browser          Maseru         tablet         1
# 3      4       2       BlackBerry          Maseru         mobile         3
# 4      5       4       BlackBerry           Soest         mobile         4
# 5      6       1           Chrome      Vila Velha         mobile         1
# 6      7       1           Chrome        Pretoria         mobile         2
# 7      8       2           Chrome       Centurion         mobile         2
# 8      9       2           Chrome         Midrand         mobile         4
# 9     10       2           Chrome         Sandton         mobile         2
# 10    11       2           Chrome      Roodepoort         mobile         2
# 11    12       0           Chrome    Johannesburg         mobile         3
# 12    13       1           Chrome       Germiston         mobile         1
# 13    14       1           Chrome       Kroonstad         mobile         1
# 14    15       1           Chrome    Bloemfontein         mobile         1
# 15    16      33           Chrome          Maseru         mobile        74
# 16    17       6           Chrome          Durban         mobile         6
# 17    18       1           Chrome           Ixopo         mobile         1
# 18    19       1           Chrome          Sydney         mobile         2
# 19    20       3           Chrome       Cape Town         mobile         8
# 20    21       1           Chrome       Asheville         mobile         1
# 21    22       0           Chrome         Detroit         mobile         1
# 22    23       1           Chrome      Birmingham         mobile         1
# 23    24       2           Chrome        Pretoria         tablet         2
# 24    25       4           Chrome    Johannesburg         tablet         4
# 25    26       3           Chrome          Maseru         tablet        11
# 26    27       1           Chrome       (not set)         tablet         1
# 27    28       0           Chrome    Johannesburg        desktop         1
# 28    29       0           Chrome          Maseru        desktop        10
# 29    30       2           Chrome       (not set)        desktop         2
# ..   ...     ...              ...             ...            ...       ...
# 117  118       0            Opera          Maseru         mobile         1
# 118  119       1            Opera          Maseru        desktop         2
# 119  120       0       Opera Mini         Nairobi         mobile         1
# 120  121       4       Opera Mini       (not set)         mobile         6
# 121  122       2       Opera Mini         Nairobi         mobile         4
# 122  123      13       Opera Mini       (not set)         mobile        16
# 123  124       2       Opera Mini         Nairobi         mobile         3
# 124  125       2       Opera Mini       (not set)         mobile         2
# 125  126       1       Opera Mini       (not set)         mobile         2
# 126  127       1           Safari       (not set)        desktop         1
# 127  128      20           Safari          Maseru        desktop        24
# 128  129       1           Safari  Port Elizabeth        desktop         1
# 129  130      12           Safari            Rome        desktop        17
# 130  131       1           Safari        Waalwijk        desktop         1
# 131  132       2           Safari    Antananarivo         mobile         2
# 132  133       1           Safari       Centurion         mobile         1
# 133  134       0           Safari          Maseru         mobile         1
# 134  135       1           Safari          Maseru         tablet         4
# 135  136       1           Safari      Hardenberg         tablet         1
# 136  137      10           Safari          Gnesta         tablet        11
# 137  138       1  Safari (in-app)    Johannesburg         mobile         1
# 138  139       0  Safari (in-app)          Maseru         mobile         1
# 139  140       1  Safari (in-app)          Maseru         tablet         1
# 140  141       1  Safari (in-app)         Chicago         tablet         1
# 141  142       5       UC Browser           Dubai         mobile         7
# 142  143       2       UC Browser          Putney         mobile         3
# 143  144       0       UC Browser         Bedford         mobile         1
# 144  145       1       UC Browser          Maseru         mobile         1
# 145  146       1       UC Browser       (not set)         mobile         2
# 146  147       2        YaBrowser          Moscow        desktop         2
#
#      latitude longitude newUsers operatingSystem pageLoadTime  \
# 0    -29.3632   27.5144        3         Android            0
# 1    -29.8518   30.9934        1         Android            0
# 2    -29.3632   27.5144        1         Android            0
# 3    -29.3632   27.5144        3      BlackBerry            0
# 4     52.1764    5.2992        4      BlackBerry       140185
# 5    -20.3478  -40.2949        1         Android            0
# 6    -25.7479   28.2293        2         Android            0
# 7     -25.864   28.0889        2         Android            0
# 8    -25.9992   28.1263        2         Android            0
# 9    -26.1076   28.0567        2         Android            0
# 10   -26.1201   27.9015        2         Android            0
# 11   -26.2041   28.0473        1         Android            0
# 12   -26.2259   28.1708        1         Android            0
# 13   -27.6373   27.2323        1         Android            0
# 14   -29.0852   26.1596        1         Android            0
# 15   -29.3632   27.5144       39         Android        19677
# 16   -29.8587   31.0218        2         Android            0
# 17   -30.1532   30.0694        1         Android            0
# 18   -33.8675   151.207        1         Android            0
# 19   -33.9249   18.4241        4         Android            0
# 20    35.5951  -82.5515        1         Android            0
# 21    42.3314  -83.0458        1         Android            0
# 22    52.4862   -1.8904        1         Android            0
# 23   -25.7479   28.2293        2         Android            0
# 24   -26.2041   28.0473        1         Android            0
# 25   -29.3632   27.5144        7         Android            0
# 26          0         0        0         Android            0
# 27   -26.2041   28.0473        1           Linux            0
# 28   -29.3632   27.5144        4           Linux            0
# 29          0         0        2           Linux            0
# ..        ...       ...      ...             ...          ...
# 117  -29.3632   27.5144        1         Android            0
# 118  -29.3632   27.5144        1         Windows            0
# 119   -1.2921   36.8219        1       (not set)            0
# 120         0         0        4       (not set)            0
# 121   -1.2921   36.8219        3         Android            0
# 122         0         0       14         Android            0
# 123   -1.2921   36.8219        3      BlackBerry            0
# 124         0         0        2      BlackBerry            0
# 125         0         0        1   Windows Phone            0
# 126         0         0        1           Linux            0
# 127  -29.3632   27.5144        1       Macintosh            0
# 128  -33.7139   25.5207        1       Macintosh            0
# 129   41.9028   12.4964        1       Macintosh            0
# 130   51.6879    5.0575        1       Macintosh            0
# 131  -18.8792   47.5079        1             iOS            0
# 132   -25.864   28.0889        1             iOS            0
# 133  -29.3632   27.5144        1             iOS            0
# 134  -29.3632   27.5144        3             iOS            0
# 135   52.5754    6.6167        1             iOS            0
# 136   59.0483   17.3072        1             iOS            0
# 137  -26.2041   28.0473        1             iOS            0
# 138  -29.3632   27.5144        1             iOS            0
# 139  -29.3632   27.5144        1             iOS            0
# 140   41.8781  -87.6298        1             iOS            0
# 141   25.2048   55.2708        1         Android            0
# 142   42.9753  -72.5217        2         Android            0
# 143    52.136   -0.4667        0         Android            0
# 144  -29.3632   27.5144        0             iOS            0
# 145         0         0        1             iOS            0
# 146   55.7558   37.6173        2         Windows            0
#
#                       region sessions users
# 0                  (not set)        4     3
# 1              KwaZulu-Natal        2     1
# 2                  (not set)        1     1
# 3                  (not set)        3     3
# 4                    Utrecht        4     4
# 5    State of Espirito Santo        1     1
# 6                    Gauteng        2     2
# 7                    Gauteng        2     2
# 8                    Gauteng        4     2
# 9                    Gauteng        2     2
# 10                   Gauteng        2     2
# 11                   Gauteng        3     1
# 12                   Gauteng        1     1
# 13                Free State        1     1
# 14                Free State        1     1
# 15                 (not set)       74    43
# 16             KwaZulu-Natal        6     2
# 17             KwaZulu-Natal        1     1
# 18           New South Wales        2     1
# 19              Western Cape        8     4
# 20            North Carolina        1     1
# 21                  Michigan        1     1
# 22                   England        1     1
# 23                   Gauteng        2     2
# 24                   Gauteng        4     1
# 25                 (not set)       11     7
# 26                 (not set)        1     1
# 27                   Gauteng        1     1
# 28                 (not set)       10     4
# 29                 (not set)        2     2
# ..                       ...      ...   ...
# 117                (not set)        1     1
# 118                (not set)        2     1
# 119                (not set)        1     1
# 120                (not set)        6     4
# 121                (not set)        4     3
# 122                (not set)       16    14
# 123                (not set)        3     3
# 124                (not set)        2     2
# 125                (not set)        2     1
# 126               Washington        1     1
# 127                (not set)       24     2
# 128             Eastern Cape        1     1
# 129                    Lazio       17     1
# 130            North Brabant        1     1
# 131                (not set)        2     1
# 132                  Gauteng        1     1
# 133                (not set)        1     1
# 134                (not set)        4     3
# 135               Overijssel        1     1
# 136      Sodermanland County       11     1
# 137                  Gauteng        1     1
# 138                (not set)        1     1
# 139                (not set)        1     1
# 140                 Illinois        1     1
# 141                    Dubai        7     2
# 142                  Vermont        3     2
# 143                  England        1     1
# 144                (not set)        1     1
# 145                (not set)        2     1
# 146                   Moscow        2     2
#
# [147 rows x 14 columns]

# %%
df2[['bounces', 'entrances', 'newUsers', 'sessions', 'users']] = df2[['bounces', 'entrances', 'newUsers', 'sessions', 'users']].astype(int)

# %%
df2.dtypes
# Out:
#                    object
# bounces             int64
# browser            object
# city               object
# deviceCategory     object
# entrances           int64
# latitude           object
# longitude          object
# newUsers            int64
# operatingSystem    object
# pageLoadTime       object
# region             object
# sessions            int64
# users               int64
# dtype: object

# %% [markdown]
# ### Finding the top 5 cities with their associated regions:
# * First select users, city and region fields from the table
# * Second group by region, then city (order matters!)
# * Use the sum function to add up relevant users
# * Sort the values by the sums
# * Take the bottom 5 (Sort is ascending)

# %%
usersPerCity = df2[['users', 'city', 'region']].groupby(['region', 'city']).sum().sort_values(by='users')
usersPerCity.tail()
# Out:
#                            users
# region       city
# Gauteng      Johannesburg     12
#              Pretoria         13
# Western Cape Cape Town        15
# (not set)    (not set)        55
#              Maseru          215

# %% [markdown]
# ### Creating a pie chart with the information
# * Simply call ```.plot.pie(subplots=True, figsize=)```
# * Subplots is ```True``` is the default

# %%
#Top 5 region and city combinations
usersPerCity.tail().plot.pie(subplots=True, figsize=(15, 8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1186cda10>], dtype=object)

# %% [markdown]
# ### A similar analysis of one variable

# %%
usersPerRegion = df2[['users', 'region']].groupby(['region']).sum().sort_values(by='users')
usersPerRegion.tail().plot.pie(subplots=True,figsize=(15,8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x118fc5810>], dtype=object)

# %% [markdown]
# ### In order to figure out new users each day:
# * Create a typed date field in order to use default time-series behavior
# * Create a new table using the same methods as before
# * Use ```.plot()``` for the visualization with no arguments as time-series line graphs are the default

# %%
df['date'] = pd.to_datetime(df['date'],infer_datetime_format=True)#format="%y-%m-%d")
df['date']
newUsersPerDay = df[['newUsers','date','users']].groupby('date', as_index=True).sum()
newUsersPerDay
# Out:
#             newUsers  users
# date
# 2016-06-18         5     19
# 2016-06-19         2     10
# 2016-06-20         7     39
# 2016-06-21         0     34
# 2016-06-22         2     62
# 2016-06-23        12     94
# 2016-06-24         1     87
# 2016-06-25         5     32
# 2016-06-26         3     28
# 2016-06-27         5     54
# 2016-06-28         5     80
# 2016-06-29         1     50
# 2016-06-30         2     44
# 2016-07-01        14     55
# 2016-07-02         1      9
# 2016-07-03         0      6
# 2016-07-04         6     81
# 2016-07-05         4     43
# 2016-07-06         4     25
# 2016-07-07         6     66
# 2016-07-08         3     25
# 2016-07-09         2      7
# 2016-07-10         4      5
# 2016-07-11         6     30
# 2016-07-12        11     50
# 2016-07-13         2     32
# 2016-07-14         3     22
# 2016-07-15        29    114
# 2016-07-16        31    110
# 2016-07-17        27     76
# 2016-07-18       100    440

# %%
newUsersPerDay.plot()

# %% [markdown]
# ### Answering the devices and OSs question
# * Create a new table with the desired data
# * ```.plot()```!

# %%
devicesAndCategories = df2[['deviceCategory', 'operatingSystem', 'users']].groupby(['deviceCategory', 'operatingSystem']).sum()
devicesAndCategories.plot.pie(subplots=True, figsize=(15, 8), autopct='%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x119d1f750>], dtype=object)

# %% [markdown]
# ### With one variable

# %%
df2[['deviceCategory','users']].groupby(['deviceCategory']).sum().plot.pie(subplots=True, figsize=(15,8), autopct='%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11b825e50>], dtype=object)

# %% [markdown]
# ### Your boss: "That's too much data! Can I just look at desktop users?"
# #### You: "Yes, of course"
#
# ### How?
# * Select conditions: ```.isin()```
# * Use ```autopct=``` to show percentages on the chart

# %%
desktopBrowserAndOS = df2[df2['deviceCategory'].isin(['desktop'])][['browser', 'users', 'operatingSystem']]
desktopBrowserAndOS.groupby(['operatingSystem']).sum().plot.pie(subplots=True, figsize=(15,8), autopct='%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11bb30b10>], dtype=object)

# %% [markdown]
# ### Your boss: "What browsers are they using on desktops?"
# #### You: "Got it!"

# %%
desktopBrowserAndOS.groupby(['operatingSystem', 'browser']).sum().plot.pie(subplots=True, figsize=(15,8), autopct='%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11c05a390>], dtype=object)

# %% [markdown]
# ### Your boss: "...just browsers?"

# %%
desktopBrowserAndOS.groupby(['browser']).sum().plot.pie(subplots=True, figsize=(15,8), autopct='%.2f')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x11ca321d0>], dtype=object)
